# %%
import requests
import os
from lxml import etree
import random
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'
}
url = 'http://sc.chinaz.com/jianli/free.html'
response = requests.get(url=url,headers=headers)
response.encoding = 'utf-8'
page_text = response.text

if not os.path.exists('jianli'):
    os.mkdir('jianli')
tree = etree.HTML(page_text)
div_list = tree.xpath('//div[@id="container"]/div')
for div in div_list:
    detail_url = div.xpath('./a/@href')[0]
    name = div.xpath('./a/img/@alt')[0]
    
    detail_page_text = requests.get(url=detail_url,headers=headers).text
    tree = etree.HTML(detail_page_text)
    download_url_list = tree.xpath('//div[@class="clearfix mt20 downlist"]/ul/li/a/@href')
    download_url = random.choice(download_url_list)
    
    jianli_data = requests.get(url=download_url,headers=headers).content
    
    file_path = 'jianli/'+name+'.rar'
    with open(file_path,'wb') as fp:
        fp.write(jianli_data)
    print(file_path+'下载成功')
# Out:
# jianli/财务管理求职简历模板下载.rar下载成功
# jianli/工程师简历自我介绍.rar下载成功
# jianli/毕业实习简历模板下载word格式.rar下载成功
# jianli/美容护士简历模板下载.rar下载成功
# jianli/口腔医生简历封面模板.rar下载成功
# jianli/外企求职简历模板.rar下载成功
# jianli/大学生实习简历表模板下载.rar下载成功
# jianli/驾驶员个人求职简历范文.rar下载成功
# jianli/word数学老师简历模板.rar下载成功
# jianli/化妆助理求职简历模板.rar下载成功
# jianli/军人个人简历表格图片.rar下载成功
# jianli/舞蹈生求职简历模板.rar下载成功
# jianli/护理个人简介Word模板下载.rar下载成功
# jianli/口腔医师电子版简历模板.rar下载成功
# jianli/行政人事个人简历范文.rar下载成功
# jianli/幼儿园简历模板下载word格式.rar下载成功
# jianli/高中生个人简历表格下载.rar下载成功
# jianli/ 数学老师求职简历模板.rar下载成功
# jianli/免费求职应聘简历模板.rar下载成功
# jianli/幼儿教师求职简历表格.rar下载成功

# %%
#处理多页
import requests
import os
from lxml import etree
import random
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36',
    'Connection':'close'
}
start_page = 1
end_page = 5

if not os.path.exists('jianli'):
        os.mkdir('jianli')
        
url = 'http://sc.chinaz.com/jianli/free_%d.html'

for page in range(start_page,end_page+1):
    if page == 1:
        new_url = 'http://sc.chinaz.com/jianli/free.html'
    else:
        new_url = format(url%page)

    response = requests.get(url=new_url,headers=headers)
    response.encoding = 'utf-8'
    page_text = response.text

    tree = etree.HTML(page_text)
    div_list = tree.xpath('//div[@id="container"]/div')
    for div in div_list:
        detail_url = div.xpath('./a/@href')[0]
        name = div.xpath('./a/img/@alt')[0]

        detail_page_text = requests.get(url=detail_url,headers=headers).text
        tree = etree.HTML(detail_page_text)
        download_url_list = tree.xpath('//div[@class="clearfix mt20 downlist"]/ul/li/a/@href')
        download_url = random.choice(download_url_list)

        jianli_data = requests.get(url=download_url,headers=headers).content

        file_path = 'jianli/'+name+'.rar'
        with open(file_path,'wb') as fp:
            fp.write(jianli_data)
        print(file_path+'下载成功')
# Out:
# jianli/财务管理求职简历模板下载.rar下载成功
# jianli/工程师简历自我介绍.rar下载成功
# jianli/毕业实习简历模板下载word格式.rar下载成功
# jianli/美容护士简历模板下载.rar下载成功
# jianli/口腔医生简历封面模板.rar下载成功
# jianli/外企求职简历模板.rar下载成功
# jianli/大学生实习简历表模板下载.rar下载成功
# jianli/驾驶员个人求职简历范文.rar下载成功
# jianli/word数学老师简历模板.rar下载成功
# jianli/化妆助理求职简历模板.rar下载成功
# jianli/军人个人简历表格图片.rar下载成功
# jianli/舞蹈生求职简历模板.rar下载成功
# jianli/护理个人简介Word模板下载.rar下载成功
# jianli/口腔医师电子版简历模板.rar下载成功
# jianli/行政人事个人简历范文.rar下载成功
# jianli/幼儿园简历模板下载word格式.rar下载成功
# jianli/高中生个人简历表格下载.rar下载成功
# jianli/ 数学老师求职简历模板.rar下载成功
# jianli/免费求职应聘简历模板.rar下载成功
# jianli/幼儿教师求职简历表格.rar下载成功
# jianli/化妆品销售个人简历模版.rar下载成功
# jianli/网络管理通用简历模板.rar下载成功
# jianli/博士英文简历模板下载.rar下载成功
# jianli/汽车专业简历封面模板下载.rar下载成功
# jianli/IT行业个人简历word模板.rar下载成功
# jianli/自媒体个人简历范文.rar下载成功
# jianli/教师招聘简历模板下载.rar下载成功
# jianli/医学硕士个人简历模板.rar下载成功
# jianli/工程造价个人简历表格.rar下载成功
# jianli/心理咨询师应聘简历模板.rar下载成功
# jianli/驾驶员个人简历范文.rar下载成功
# jianli/汽车美容个人简历模板下载.rar下载成功
# jianli/传媒专业简历模板.rar下载成功
# jianli/列车员简历模版word下载.rar下载成功
# jianli/医学生专用个性简历模版.rar下载成功
# jianli/中专生简历模板范文.rar下载成功
# jianli/求职简历的表格电子版.rar下载成功
# jianli/研究生优秀个人简历模版.rar下载成功
# jianli/Word模板英文简历下载.rar下载成功
# jianli/市场推广实用简历模板.rar下载成功
# jianli/航空公司面试封面模板.rar下载成功
# jianli/网络销售个人简历模板.rar下载成功
# jianli/艺术生求职简历范文.rar下载成功
# jianli/幼师个人简历封面下载.rar下载成功
# jianli/服装设计简历模板下载word.rar下载成功
# jianli/军人个人简历表格.rar下载成功
# jianli/大学生求职简历封面下载.rar下载成功
# jianli/医学生求职简历模板免费下载.rar下载成功
# jianli/船员简历表格下载.rar下载成功
# jianli/个人简历模板学前教育.rar下载成功
# jianli/服务员简历模板下载word格式.rar下载成功
# jianli/学前教育类简历模板.rar下载成功
# jianli/大学生会计求职简历模板下载.rar下载成功
# jianli/钢琴老师求职简历封面.rar下载成功
# jianli/机械维护英文简历模板.rar下载成功
# jianli/应聘酒店管理个人简历下载.rar下载成功
# jianli/护理专业实习简历表格.rar下载成功
# jianli/ 销售应聘个人简历范文.rar下载成功
# jianli/发型师总监个人简历下载.rar下载成功
# jianli/环境工程专业简历模板.rar下载成功
# jianli/厨师个人简历下载word格式.rar下载成功
# jianli/音乐求职简历封面模板.rar下载成功
# jianli/空乘简历模板电子.rar下载成功
# jianli/应届师范生个人简历模板.rar下载成功
# jianli/师范生个人简历下载word格式.rar下载成功
# jianli/ 地理老师求职简历封面.rar下载成功
# jianli/大学毕业生求职简历模板下载.rar下载成功
# jianli/空乘面试个人简历模板.rar下载成功
# jianli/传媒个人简历模板范文.rar下载成功
# jianli/酒店厨师简历表格下载.rar下载成功
# jianli/临床医学专业简历模板.rar下载成功
# jianli/中专生个人简历模板范文.rar下载成功
# jianli/工程造价个人简历表格模板.rar下载成功
# jianli/ 英文版电子简历下载.rar下载成功
# jianli/电子商务个人简历模板免费下载.rar下载成功
# jianli/应聘空乘简历模板.rar下载成功
# jianli/大学个人简历模板word.rar下载成功
# jianli/行政人事简历模板下载.rar下载成功
# jianli/医学生求职简历模板word.rar下载成功
# jianli/幼儿园个人简历表格模板.rar下载成功
# jianli/电商设计师简历模板下载.rar下载成功
# jianli/ 文科生简历封面图片.rar下载成功
# jianli/大学生自我评价简历范文.rar下载成功
# jianli/外贸业务员个人简历模板.rar下载成功
# jianli/java程序员求职简历模板.rar下载成功
# jianli/电商简历封面模板.rar下载成功
# jianli/医学影像学简历模板.rar下载成功
# jianli/运营经理个人简历模板.rar下载成功
# jianli/市场营销总监简历模板下载.rar下载成功
# jianli/ 自荐书封面模板下载.rar下载成功
# jianli/美容专业简历模板下载.rar下载成功
# jianli/音乐教师个人简介模板.rar下载成功
# jianli/护士求职简历模板范文.rar下载成功
# jianli/ 投行简历模板下载word格式.rar下载成功
# jianli/学前教育教师个人简历模板.rar下载成功
# jianli/银行应聘个人简历模板.rar下载成功
# jianli/品牌总监个人简历模板.rar下载成功
# jianli/求职简历模板医学类.rar下载成功
# jianli/大学生自我简介模板.rar下载成功
# jianli/房地产应聘简历表格模板.rar下载成功
