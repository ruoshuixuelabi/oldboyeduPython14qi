# %% [markdown]
# - 环境安装:pip install lxml
# - xpath解析原理:
#     - 标签定位
#     - xpath表达式进行标签的定位
#     - xpath表达式必须作用在xpath函数中
#     - xpath函数是被封装在etree对象

# %%
from lxml import etree

# %%
#实例化一个etree对象并且页面源码数据加载到该对象中
tree = etree.parse('./test.html')

# %%
#解析操作
tree.xpath('//div[@class="song"]/p[4]')
# Out:
# [<Element p at 0x4fd1e08>]

# %%
tree.xpath('//div[@class="song"]/p[4]/text()')[0]
# Out:
# '柳宗元'

# %%
tree.xpath('//div[@class="song"]//text()')
# Out:
# ['\n\t\t',
#  '李清照',
#  '\n\t\t',
#  '王安石',
#  '\n\t\t',
#  '苏轼',
#  '\n\t\t',
#  '柳宗元',
#  '\n\t\t',
#  '\n\t\t\t',
#  'this is span',
#  '\n\t\t宋朝是最强大的王朝，不是军队的强大，而是经济很强大，国民都很有钱',
#  '\n\t\t',
#  '总为浮云能蔽日,长安不见使人愁',
#  '\n\t\t',
#  '\n\t']

# %% [markdown]
# /text()  - > 只有一个元素的列表
# //text() - > 有多个元素的列表

# %%
tree.xpath('//div[@class="tang"]/ul/li[2]/a/@href')
# Out:
# ['http://www.163.com']

# %%
etree.HTML(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-73dddeb06a6b> in <module>()
# ----> 1 etree.HTML(response.text)
#
# NameError: name 'response' is not defined

# %%
#需求:解析获取58二手房相关的数据

# %%
import requests
from lxml import etree

# %%
#获取页面源码数据
url = 'https://bj.58.com/changping/ershoufang/?utm_source=sem-baidu-pc&spm=105916147073.26840108910'
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'
}
page_text = requests.get(url=url,headers=headers).text

#实例化etree对象且将页面源码数据加载到该对象中
tree = etree.HTML(page_text)
li_list = tree.xpath('//ul[@class="house-list-wrap"]/li')
all_data_list = []
for li in li_list:
    title = li.xpath('.//div[@class="list-info"]/h2/a/text()')[0]
    detail_url = li.xpath('.//div[@class="list-info"]/h2/a/@href')[0]
    if not 'https:' in detail_url:
        detail_url = 'https:'+detail_url
    price = li.xpath('.//div[@class="price"]/p//text()')
    price = ''.join(price)
    
    #对详情页发起请求,获取页面数据
    detail_page_text = requests.get(url=detail_url,headers=headers).text
    tree = etree.HTML(detail_page_text)
    desc = tree.xpath('//div[@class="general-item-wrap"]//text()')
    desc = ''.join(desc).strip(' \n \b \t')
    
    dic = {
        'title':title,
        'price':price,
        'desc':desc
    }
    all_data_list.append(dic)
    
print(all_data_list)
# Out:
# [{'title': '西环里~南北两居~有小院和客厅~看房有钥匙\xa0', 'price': '218万40110元/㎡', 'desc': '房屋总价\n                            \n                                    鑶龤龥万(单价驋餼龤龤餼元/㎡)\n                                \n                        \n                                                                \n                            房屋户型\n                            2室1厅1卫\n                        \n                                                                \n                            房本面积\n                            54.35㎡\n                        \n                                                                \n                            房屋朝向\n                            东\n                        \n                                    \n                \n                                            \n                            所在楼层\n                            共5层\n                        \n                                                                \n                            装修情况\n                            简单装修\n                            \n                                    \n                                        找装修\n                                    \n                            \n                        \n                                                                \n                            产权年限\n                            70年\n                        \n                                                                \n                            建筑年代\n                            1983年\n                        \n                                    \n            \n                                    \n                            \n                                核心卖点\n                            \n                        1.房子是南北通透的两居室  一进门可以当成一正规的客厅 南北各一卧室 通透性好。2.房子北面有10平米左右的储藏室和车棚 南面是一20平米的小院。3.看房还有钥匙，随时看。4.小区是一个成熟的社区，配套齐全。\n                    \n                                                    \n                            \n                                业主心态\n                            \n                        \n                            业主特意把钥匙留给了我们公司一把，方便客户看房。\n                        \n                    \n                                                                                    \n                            \n                                服务介绍\n                            \n                        \n                            收取服务费：最高43600元(≤2.0%)从事昌平二手房买卖和租赁已经五年有余而且是本小区的小区专家！对昌平的各个地段和周边情况十分熟知，本人怀揣昌平欢迎您的热忱态度，服务于每一位客户！再次我要感谢那些曾经陪伴我的客户和房主，正是因为您们给予的信任让我有更多的机会不断成长！政策*，市场波动，我的专业、坚定在洗礼中经历的考验成功法则，让我相信，我会用我的陪伴和知识，让您在昌平安家置业！\n                        \n                    \n                                                    \n                            \n                                核验编号\n                            \n                        \n                            北京市城乡房产管理局：暂未完成认证\n                        \n                    \n                \n                                                    \n                        \n                            房源编号\n                        \n                        \n                            房源编号：661578042394624\n                        \n                    \n                            \n                \n                    房屋总价\n                        \n                                鑶龤龥万（单价驋餼龤龤餼元/㎡）\n                            \n                        \n                                帮你凑钱\n                                \n                            \n                    \n                                            \n                            房屋类型\n                            普通住宅\n                        \n                                                                \n                            交易权属\n                            商品房\n                        \n                                                                                                                    \n                \n                  ...
